# %% [markdown]
# # 👋🌍 Hello, world: Submit a Q# job to IonQ
#
# In this notebook, we'll review the basics of Azure Quantum by submitting a simple *job*, or quantum program, to [IonQ](https://ionq.com/). We will use [Q#](https://docs.microsoft.com/azure/quantum/user-guide/) to express the quantum job.
#
# **Instructions:** Make sure  to download this notebook and upload it into Azure Quantum in order to follow along.

# %% [markdown]
# ## Submit a simple job to IonQ using Azure Quantum
# Azure Quantum provides several ways to express quantum programs. In this example we are using Q#, but note that Qiskit and Cirq are also supported. All code in this example will be written in Python and Q#.
#
#
#
# **The following is what you should see if you have logged in your Workspace with your Azure Quantum account. If you are still having trouble, please don't hesitate to reach out to the Qubit by Qubit team!**

# %% [markdown]
# ![Screen Shot 2023-01-27 at 3.40.34 AM.jpg](data:image/jpeg;base64,...)
#
# ### 1. Connect to the Azure Quantum workspace
#
# Let's begin. When you see a code block, hover over it and click the triangle play-button to execute it. To avoid any compilation issues, this should be done in order from top to bottom.
# To connect to the Azure Quantum service, call the `connect` function as seen below. This can take 30 seconds to run the first time, as the Q# environment is initializing.

# %%
import qsharp.azure
targets = qsharp.azure.connect(
    resourceId="/subscriptions/943c06da-431c-4d1f-a9b4-9e32ce8384d6/resourceGroups/Lab1Introductory/providers/Microsoft.Quantum/Workspaces/Welcome2AzureQuant",
    location="westcentralus")
# Out:
# Connecting to Azure Quantum...
# The Azure Quantum workspace Welcome2AzureQuant in location westcentralus could not be reached. Please check the provided parameters and try again.
# Error details:
#
# There are not enough permissions to perform this operation.
# Status: 403 (Forbidden)
# ErrorCode: InsufficientPermissions
#
# Content:
# {"error":{"code":"InsufficientPermissions","message":"There are not enough permissions to perform this operation."}}
#
# Headers:
# Date: Wed, 01 Feb 2023 21:14:23 GMT
# Connection: keep-alive
# Set-Cookie: REDACTED
# Server: Microsoft-IIS/10.0
# Request-Context: REDACTED
# Strict-Transport-Security: REDACTED
# mise-correlation-id: REDACTED
# x-ms-request-id: 453281523d6b443b
# X-Powered-By: REDACTED
# Content-Type: application/json; charset=utf-8
# Content-Length: 116
# ---------------------------------------------------------------------------
# AzureError                                Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 import qsharp.azure
# ----> 2 targets = qsharp.azure.connect(
#       3     resourceId="/subscriptions/943c06da-431c-4d1f-a9b4-9e32ce8384d6/resourceGroups/Lab1Introductory/providers/Microsoft.Quantum/Workspaces/Welcome2AzureQuant",
#       4     location="westcentralus")
#
# File /usr/local/lib/python3.9/site-packages/qsharp/azure.py:122, in connect(**params)
#     117 """
#     118 Connects to an Azure Quantum workspace or displays current connection status.
#     119 See https://docs.microsoft.com/qsharp/api/iqsharp-magic/azure.connect for more details.
#     120 """
#     121 result = qsharp.client._execute_magic(f"azure.connect", raise_on_stderr=False, **params)
# --> 122 if "error_code" in result: raise AzureError(result)
#     123 return [AzureTarget(target) for target in result]
#
# AzureError: {'error_code': 1013, 'error_name': 'WorkspaceNotFound', 'error_description': 'No Azure Quantum workspace was found that matches the specified criteria.'}
# Authenticated using Microsoft.Azure.Quantum.Authentication.TokenFileCredential
#
#
# fail: Microsoft.Quantum.IQSharp.AzureClient.AzureClient[0]
#       The Azure Quantum workspace Welcome2AzureQuant in location westcentralus could not be reached.
#       Azure.RequestFailedException: There are not enough permissions to perform this operation.
#       Status: 403 (Forbidden)
#       ErrorCode: InsufficientPermissions
#
#       Content:
#       {"error":{"code":"InsufficientPermissions","message":"There are not enough permissions to perform this operation."}}
#
#       Headers:
#       Date: Wed, 01 Feb 2023 21:14:23 GMT
#       Connection: keep-alive
#       Set-Cookie: REDACTED
#       Server: Microsoft-IIS/10.0
#       Request-Context: REDACTED
#       Strict-Transport-Security: REDACTED
#       mise-correlation-id: REDACTED
#       x-ms-request-id: 453281523d6b443b
#       X-Powered-By: REDACTED
#       Content-Type: application/json; charset=utf-8
#       Content-Length: 116
#
#          at Azure.Quantum.Jobs.ProvidersRestClient.GetStatusAsync(CancellationToken cancellationToken)
#          at Azure.Quantum.Jobs.QuantumJobClient.<GetProviderStatusAsync>b__10_0(String cont)
#          at Azure.Core.PageResponseEnumerator.FuncAsyncPageable`1.AsPages(String continuationToken, Nullable`1 pageSizeHint)+MoveNext()
#          at Azure.Core.PageResponseEnumerator.FuncAsyncPageable`1.AsPages(String continuationToken, Nullable`1 pageSizeHint)+System.Threading.Tasks.Sources.IValueTaskSource<System.Boolean>.GetResult()
#          at Azure.AsyncPageable`1.GetAsyncEnumerator(CancellationToken cancellationToken)+MoveNext()
#          at Azure.AsyncPageable`1.GetAsyncEnumerator(CancellationToken cancellationToken)+MoveNext()
#          at Azure.AsyncPageable`1.GetAsyncEnumerator(CancellationToken cancellationToken)+System.Threading.Tasks.Sources.IValueTaskSource<System.Boolean>.GetResult()
#          at Microsoft.Azure.Quantum.Workspace.ListProvidersStatusAsync(CancellationToken cancellationToken)+MoveNext() in D:\a\1\s\submodules\qsharp-runtime\src\Azure\Azure.Quantum.Client\JobManagement\Workspace.cs:line 239
#          at Microsoft.Azure.Quantum.Workspace.ListProvidersStatusAsync(CancellationToken cancellationToken)+MoveNext() in D:\a\1\s\submodules\qsharp-runtime\src\Azure\Azure.Quantum.Client\JobManagement\Workspace.cs:line 239
#          at Microsoft.Azure.Quantum.Workspace.ListProvidersStatusAsync(CancellationToken cancellationToken)+System.Threading.Tasks.Sources.IValueTaskSource<System.Boolean>.GetResult()
#          at Microsoft.Quantum.IQSharp.AzureClient.AzureClient.ConnectToWorkspaceAsync(IChannel channel, String subscriptionId, String resourceGroupName, String workspaceName, String location, TokenCredential credential, CancellationToken cancellationToken) in D:\a\1\s\submodules\iqsharp\src\AzureClient\AzureClient.cs:line 310
#          at Microsoft.Quantum.IQSharp.AzureClient.AzureClient.ConnectToWorkspaceAsync(IChannel channel, String subscriptionId, String resourceGroupName, String workspaceName, String location, TokenCredential credential, CancellationToken cancellationToken) in D:\a\1\s\submodules\iqsharp\src\AzureClient\AzureClient.cs:line 310

# %% [markdown]
# This output should display. We then ![Screen Shot 2023-01-27 at 3.44.27 AM.jpg](data:image/jpeg;base64,...)can use the resulting object to see which _targets_ are available for submission.

# %%
import qsharp

print("This workspace's targets:")
for target in targets:
    print("-", target.id)
# Out:
# This workspace's targets:
# - ionq.qpu
# - ionq.qpu.aria-1
# - ionq.simulator
# - microsoft.estimator
# - quantinuum.hqs-lt-s1
# - quantinuum.hqs-lt-s1-apival
# - quantinuum.hqs-lt-s2
# - quantinuum.hqs-lt-s2-apival
# - quantinuum.hqs-lt-s1-sim
# - quantinuum.hqs-lt-s2-sim
# - quantinuum.hqs-lt
# - quantinuum.qpu.h1-1
# - quantinuum.sim.h1-1sc
# - quantinuum.qpu.h1-2
# - quantinuum.sim.h1-2sc
# - quantinuum.sim.h1-1e
# - quantinuum.sim.h1-2e
# - quantinuum.qpu.h1
# - rigetti.sim.qvm
# - rigetti.qpu.aspen-11
# - rigetti.qpu.aspen-m-2
# - rigetti.qpu.aspen-m-3

# %% [markdown]
# ### ❕ Do you see `ionq.simulator` in your list of targets? If so, you're ready to keep going.
#
# Don't see it? You may need to add IonQ to your workspace to run this sample. Navigate to the **Providers** page in the portal and click **+Add** to add the IonQ provider. Don't worry, there's a free credits plan available.

# %% [markdown]
# ## IonQ: The quantum provider
# Azure Quantum partners with third-party companies to deliver solutions to quantum jobs. These company offerings are called *providers*. Each provider can offer multiple *targets* with different capabilities. See the table below for IonQ's targets.
#
# | Target name | Target ID | Number of qubits | Description |
# | --- | --- | --- | --- |
# | Quantum simulator | `ionq.simulator` | 29 qubits | IonQ's cloud-based idealized simulator. Free of cost. |
# | Aria 1 | `ionq.qpu.aria-1` | 23 qubits | IonQ's Aria 1 trapped-ion quantum computer. This is real quantum hardware, not a simulation. |
# | Quantum computer | `ionq.qpu` | 11 qubits | IonQ's trapped-ion quantum computer. This is real quantum hardware, not a simulation. |
#
# For this example, we will use `ionq.simulator`. To learn more about IonQ's targets, check out our [documentation](https://docs.microsoft.com/azure/quantum/provider-ionq).

# %% [markdown]
# ### 2. Build the quantum program
#
# Let's create a simple Q# program to run. This can take 30 seconds to run the first time, as the Q# environment is initializing.

# %%
# We declare the function we will define in Q# as a callable so that Python recognizes the symbol.
GenerateRandomBit: any = None

# %%
# %%qsharp
# open Microsoft.Quantum.Measurement;
# open Microsoft.Quantum.Arrays;
# open Microsoft.Quantum.Convert;
#
# operation GenerateRandomBit() : Result {
#     use target = Qubit();
#
#     // Apply an H-gate and measure.
#     H(target);
#     return M(target);
# }

# %% [markdown]
# The program you built is a simple quantum random bit generator. With IonQ's idealized simulator, we will be able to calculate the probability of measuring a `1` or `0`.

# %% [markdown]
# ### 3. Submit the quantum program to IonQ
#
# We will use the `execute` function to run the quantum program above on IonQ's `ionq.simulator` target. This may take a minute or so ⏳. Your job will be packaged and sent to IonQ, where it will wait its turn to be run.

# %%
# ionq.simulator.execute()
# okay figure this part out  by googling
# oh okay so we save that  as result 
target = "ionq.simulator" # change this to what your instructor tells you to
qsharp.azure.target(target)

# We'll use 100 shots (simulated runs)
result = qsharp.azure.execute(GenerateRandomBit, shots=100, jobName="Generate one random bit", timeout=240)
# Out:
# Loading package Microsoft.Quantum.Providers.IonQ and dependencies...
# Active target is now ionq.simulator
# Submitting GenerateRandomBit to target ionq.simulator...
# Job successfully submitted.
#    Job name: Generate one random bit
#    Job ID: c6334322-b368-4a17-bcd9-b5270cdab6b5
# Waiting up to 240 seconds for Azure Quantum job to complete...
# [08:26:23] Current job status: Waiting
# [08:26:28] Current job status: Succeeded

# %% [markdown]
# The job ID can be used to retrieve the results later using the `output` and `status` functions or by viewing it under the **Job management** section of the portal.

# %% [markdown]
# ### 4. Visualize job results
# You can also view a histogram of the results using [`pyplot`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html):

# %%
from matplotlib import pyplot

pyplot.bar(result.keys(), result.values())
pyplot.title("Result")
pyplot.xlabel("Measurement")
pyplot.ylabel("Probability")

pyplot.show()

# %% [markdown]
# **See the histogram above? Congratulations, you've submitted a job with Azure Quantum! 👏**

# %% [markdown]
# ### 5. Next steps
# Next, you can try running a program on IonQ's hardware target - just replace `ionq.simulator` with `ionq.qpu`. Or try another sample by navigating back to the sample gallery. The same "hello world" sample can be run with different quantum providers by choosing another option in the gallery card drop-down menu. Don't worry - your work here is automatically saved.
#
# To learn more about submitting jobs to Azure Quantum using Q#, refer to [this documentation](https://docs.microsoft.com/azure/quantum/how-to-submit-jobs?pivots=ide-python).
